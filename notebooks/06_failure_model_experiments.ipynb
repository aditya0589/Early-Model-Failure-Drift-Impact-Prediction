# %% [markdown]
# # 06 Failure Model Experiments
#
# Auto-generated notebook for MLOps Project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os

# Add src to path
sys.path.append(os.path.abspath('..'))

from src.utils.config import config
from src.utils.logger import setup_logger

# %matplotlib inline
sns.set_style("whitegrid")

# %%
from src.models.failure_model import FailurePredictor
model = FailurePredictor()
try:
    model.load("../experiments/results/failure_model.joblib")
    print("Model loaded.")
except:
    print("Model not found.")

# %%
if hasattr(model.model, 'coef_'):
    coefs = model.model.coef_[0]
    features = model.feature_names
    
    coef_df = pd.DataFrame({'feature': features, 'coef': coefs})
    coef_df['abs_coef'] = coef_df['coef'].abs()
    coef_df = coef_df.sort_values('abs_coef', ascending=False).head(10)
    
    plt.figure(figsize=(12, 6))
    sns.barplot(x='coef', y='feature', data=coef_df)
    plt.title("Top 10 Features for Failure Prediction")
    plt.show()
